# %%
a,b=10,20
if(a>b):
  print("T")
else:
  print(bool(""))
# Out:
# False

# %%
def test() :
 i=1
 while (i>=1) :
   print(i)
   i=i+1

# %%
def print_string(L1):
    for i in L1:
        print("*"*i)
