# %%
a=input("Enter first name")
b=input("Enter middle name")
c=input("Enter last name")
fullname=" ".join([a,b,c])
print(fullname)
email=input("Enter email")
if email.endswith("""com,org,edu,in"""):
   print("Valid")
else:
   print("Invalid")
# Out:
# Enter first nameKrupa
# Enter middle nameKashinath
# Enter last nameSawant
# Krupa  Kashinath  Sawant
# Enter emailKrupa.in
# Invalid
